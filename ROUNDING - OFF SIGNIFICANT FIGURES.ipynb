# %%
def nxt_int(n): # Get the next consecutive integer from the given one
    if n == '0':
        n_out = '1'
    elif n == '1':
        n_out = '2'
    elif n == '2':
        n_out = '3'
    elif n == '3':
        n_out = '4'
    elif n == '4':
        n_out = '5'
    elif n == '5':
        n_out = '6'
    elif n == '6':
        n_out = '7'
    elif n == '7':
        n_out = '8'
    elif n == '8':
        n_out = '9'
    elif n == '9':
        n_out = '0'
    return n_out








def RoundingOffWholeNumbers(number):
    

  
    
    
   
   f=","
   index=number.find(f)
   number1=number[:index]
   original_number1=number1
   number2=int(number[index+1:])
   
   #print("original_number1",original_number1)
   #print("NUmber2",number2)
   check_number=int(number1[-number2])

  
    
   
        
   in_num_str=number1

           #check_number=int(number1[-number2])
           #print(check_number)
    
           #n3=number2-1
           #if(n3==0):
            #    in_num_str=number1
           #else:
               #in_num_str = str(number1[:-(n3)])
               #print(in_num_str)
    # Determine if the last digit is closer to 0 or 10
   #number2=number2+1
   if (check_number >= 5):
        # Eliminate the decimal point
                    in_num_str_split = ''.join(in_num_str.split('.'))
                    #print("In num str split",in_num_str_split)
        # Get the length of the integer portion of the number
                    int_len = len(in_num_str.split('.')[0])
        # Initialize the variables used in the loop
                    out_num_str = ''
                    done = False
                    count=0
                    count1=0
                    zero1=0
        # Loop over all the digits except the last digit in reverse order
                    for num in in_num_str_split[::-1]:
            # Get the next consecutive integer\
                        count1=count1+1
                        #print("Count1",count1)
                        num_nxt_int = nxt_int(num)
                        
                        #print("Num",num)
                        #print("In_num_str_split",in_num_str_split[-2])
                       # print("Out num str",out_num_str)
            # Determine if the current digit needs to be increased by one
                        #if (num_nxt_int == '0' or num == in_num_str_split[-2] or out_num_str[-1] == '0') and not done:
                         #   out_num_str = out_num_str + num_nxt_int
                        #else:
                         #   out_num_str = out_num_str + num
                          #  done = True
        # Build the rounded decimal
                        #print("num_nxt_int",num_nxt_int)
                        #out_num_str=num_nxt_int+out_num_str
                       # print("count1",count1)
                        #print("number2",number2)
                        #print("number1",number1)
                        #print(num_nxt_int)
                        if(count1==number2 and num_nxt_int!='0'):
                            #out_num_str=out_num_str[1:]
                           # print(number1[:-count1])
                            #out_num_str=num_nxt_int+out_num_str 
                            #print("Out",out_num_str)
                            
                            #print("This is")
                            out_num_str=original_number1[:-(count1)]+out_num_str
                            #out_num_str=num_nxt_int+out_num_str
                            #print("Out",out_num_str)
                            return(out_num_str)
                        if(count1==number2 and num_nxt_int=='0'):
                            #out_num_str=out_num_str[1:]
                            out_num_str=num_nxt_int+out_num_str 
                            continue
                            
                            
                        if(count1>=number2 and num_nxt_int!='0'):
                            #print("OUt_",out_num_str)
                            out_num_str=num_nxt_int+out_num_str 
                            out_num_str=number1[:-(count1)]+out_num_str
                            #out_num_str=num_nxt_int+out_num_str
                           # print(out_num_str)
                            break
                        else:
                           # print("test-----")
                            out_num_str=num_nxt_int+out_num_str 
                            continue
                        #out_num_str=num_nxt_int+out_num_str
                        #elif(zero1<1 and count==number2):
                         #   out_num_str=number1[:-count1]+out_num_str
                          #  break
                        #print(out_num_str)
                        #out_num_str=out_num_str[::-1]
                        #out_num_str = (out_num_str[::-1][:int_len] + '.' + #out_num_str[::-1][int_len:]).rstrip('0').rstrip('.')
                        #print(out_num_str)
                    number1=out_num_str
                    final_number=""
                    #number1[:-number2]=out_num_str[:-number2]
                    n=(len(out_num_str)+1)-number2
                    for i in range(len(out_num_str)):
                        if(i<n):
                            final_number=final_number+out_num_str[i]
                        elif(i>=n):
                            final_number=final_number+"0"
                            
                    number1=final_number
                        
             
   #elif(int(in_num_str[1])>=5):
    #       out_num_str=str(int(in_num_str[0])+1)+out_num_str
   #elif(int(in_num_str[1])<5):
    #        out_num_str=str(int(in_num_str[0]))+out_num_str
        
    
               
   
            #print(number1[-n4])
            #print("TEST")
            
       
       
          
   else:
       zero=""
       for i in range(number2-1):
            zero=zero+"0"
       n=number2-1
       number1=number1[:(-n)]+zero 
    
   if(in_num_str[0]=='9' and int(in_num_str[1])>=5):
            number1='1'+number1
            
    
    
   #check_point=0
   #for i in original_number1:
    #    if(i=='9'):
     #       check_point=check_point+1
   #if(check_point==(len(original_number1))):
    #    zeroes=""
     #   for i in range(len(original_number1)):
      #      zeroes=zeroes+"0"
       # number1="1"+zeroes
    
    
   #if(in_num_str[0]=='9' and int(in_num_str[1])>=5):
          #  out_num_str='10'+out_num_str


    
   
   result=number1

   return(result)       





def RoundingOffSignificantFigures(number):
    
   
    
   number_name=number
   f=","
   index=number.find(f)
   count=0
   
   number1=number[:index]
   len_number1=len(number1)
   number2=int(number[index+1:])
   

   #print("number2",number2)
   #print(len_number1)

   
      
   h="."
   index1=number1.find(h)
   whole_number=number1[:index1]
   decimal_number=number1[index1+1:]
   #print(int(whole_number))
   len_whole_number=len(whole_number)
    
   if(index1>0):
           whole_number=number1[:index1]
   else:
           whole_number=number1
           ans=RoundingOffWholeNumbers(number)
           return ans
    

   if(index1>0 and (len_number1-1)==number2):
        if(int(decimal_number)==0):
            return whole_number
        else:
            return number1
   if(index1<0 and (len_number1)==number2):
        return number1
    
    
   #print(len_whole_number)
   str1=""
   count=0
   point=0
   k="NULL"
   k1="NULL"
   first=0
   for i in number1:
        #print("Main-i",i)
        
        if(i=='0' and count<number2 and first==0):
           
            str1=str1+i
        elif(i=='0' and count<number2 and first>0):
           
            str1=str1+i
            count=count+1
            #print("I",i)
            #print("count",count)
        elif(i=="." and count<=number2):
            str1=str1+i
            point=1
        elif(i!='0' and count<number2 and i!="."):
            
            count=count+1
            first=first+1
            #print(count)
            #print("i",i)
            str1=str1+i
        elif(count==number2 and i!='.' and point==1):
            #print("TEST")
            #print("Point",point)
            #str1=str1+i
            k=int(i)
            
            #print("k",k)
            break
        elif(count==number2 and i!='.' and point==0):
            #print("TEST")
            #print("Point",point)
            str1=str1+i
            k=int(i)
           
           # print("k",k)
            break
        elif(count==number2  and point!=1 and i!='.'):
           # print("TEST",test)
            str1=str1+i
            k=int(i)
            break
        elif(count==number2 and i=="."):

            count=count+1
            #number2=number2+1
            #print("COUNT",count)
            str1=str1+i
            continue
        
                
        elif(count==(number2+1)):
            k1=int(i)
            #print("Count",count)
            #print("K1",k1)
            break
        
   #print("k",k)
   #print("str1",str1)
   if(k!="NULL"):
       if((k<5) and (len_whole_number<number2)):
            return str1
       elif((k<5) and int(whole_number)==0):
            return str1
       elif(k<5 and len_whole_number>=number2 and int(whole_number)!=0):
            #print("test")
            zeroes=len_whole_number-number2
           # print(zeroes)
            str2=""
            for i in range(zeroes):
                str2=str2+"0"
            #print(str2)
            #print(str1+str2)
            return str1+str2
       elif(k>=5):
            #print("k",k)
           # print(str1[-1])
            #print(index1)
            #print(int(whole_number))
           
            if(str1[-1]=='9' and index1>0 and int(whole_number)!=0):
                   # print("Test")
    #                #print(\"str1\",str1)\n",
                    #if(number2>len(whole_number)):
                    rounding_digit=number2-(len(whole_number))
                    #else:
                    rounding_digit=len(whole_number)-number2
                    str1=str1.replace(".","")
                    str1_round=str1+","+str(rounding_digit)
                    
                    #print("str1_round",str1_round)
                    ans=RoundingOffWholeNumbers(str1_round)
                    #print("ans",ans[index1:])
                    if((ans[index1:])!=""):
                        #print("TEST")
                        ans=ans[:index1]+"."+ans[index1:]
                    else:
                        ans=ans[:index1]
                    return ans
            elif(str1[-1]=='9' and index1>0 and int(whole_number)==0):
                   # print("Test")
    #                print(\"str1\",str1)\n",
                    rounding_digit=1
                    str1=str1.replace(".","")
                    str1_round=str1+","+str(rounding_digit)
                   # print("str1_round",str1_round)
                    ans=RoundingOffWholeNumbers(str1_round)
                    ans=ans[:index1]+"."+ans[index1:]
                    return ans
            elif(k>=5 and len_whole_number>number2 and int(whole_number)!=0):
                    #print("test")
                    zeroes=len_whole_number-number2
                    #str1[-1]=str(int(str1[-1])+1)
    #                print(len_whole_number)\n",
    #                print(zeroes)\n",
                    str2=""
                    for i in range(zeroes):
                        str2=str2+"0"
    #            #print(str2)\n",
    #            #print(str1+str2)\n",
                    return str1[:-1]+str(int(str1[-1])+1)+str2
            elif (int(str1[-1])+1==10 and str1[-2]!="."):
                        #for i in range(len(str1)-1, -1, -1):\n",
                    return str1[:-2]+str(int(str1[-2])+1)
            elif(int(str1[-1])+1==10 and str1[-2]=="."):
                    return str1[:-3]+str(int(str1[-3])+1)+"."+"0"
                        
            else:
    
                    return str1[:-1]+str(int(str1[-1])+1)
    
            if(str1[-1]=='9'):
                #print("Test")
                #print("str1",str1)
                rounding_digit=number2-(len(whole_number))
                str1_round=str1+","+str(rounding_digit)
                #print(str1_round)
                ans=RoundingOffWholeNumbers(str1_round)
                return ans
            if (int(str1[-1])+1==10 and str1[-2]!="."):
                    #for i in range(len(str1)-1, -1, -1):
                    return str1[:-2]+str(int(str1[-2])+1)+"0"
            elif(int(str1[-1])+1==10 and str1[-2]=="."):
                    return str1[:-3]+str(int(str1[-3])+1)+"."+"0"
                    
            else:
                   
                    return str1[:-1]+str(int(str1[-1])+1)
   
  # print("k1",k1)
   if(k1!="NULL"):
       if(k1<5):
            return str1[:-1]
       elif(k1>=5):
            #print("STR1",str1)
            if(k1==9 and str1[-1]==9):
                str1_round=str1+","+"1"
                ans=round_decimal(str1_round)
                return ans
            if(str1[-1]=='.'):
                str1=str1[:-1]
            #print("STR1",str1)
            h=int(str1[-1])+1
            if(h==10):
                return str1[:-2]+str(int(str1[-2])+1)+"0"
                    
            else:
                return str1[:-1]+str(h)
        


y1="0.025842,3"

y2="12575.50,5"
y3="129.96,4"
y4="127.448,4"
y5="12575.20,6"
y6="0.025895,4"
y7="2303.56,4"
y8="0.0023088727601076275,4"
y9="12575.95,6"
y10="127.96,1"
y11="15.9996,4"
y12="15.9,1"
y13="199,2"

y14="0.025952,3" 
y15="199.98,4"
y16="12579.98,6"

y17="0.025895,4"

y18="12575.841,4"

y19="0.025842,1"

y20="0.02495,1"

y21="199.98,2"



  
final=RoundingOffSignificantFigures(y2)
print(final)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 454>()
#     447 y20="0.02495,1"
#     449 y21="199.98,2"
# --> 454 final=RoundingOffSignificantFigures(y2)
#     455 print(final)
#
# Input In [2], in RoundingOffSignificantFigures(number)
#     369 #            #print(str2)\n",
#     370 #            #print(str1+str2)\n",
#     371                 return str1[:-1]+str(int(str1[-1])+1)+str2
# --> 372         elif (int(str1[-1])+1==10 and str1[-2]!="."):
#     373                     #for i in range(len(str1)-1, -1, -1):\n",
#     374                 return str1[:-2]+str(int(str1[-2])+1)
#     375         elif(int(str1[-1])+1==10 and str1[-2]=="."):
#
# ValueError: invalid literal for int() with base 10: '.'
